# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# original df
df = pd.read_csv('HAM10000_metadata.csv')
df.count()
# Out:
# lesion_id       10015
# image_id        10015
# dx              10015
# dx_type         10015
# age              9958
# sex             10015
# localization    10015
# dtype: int64

# %%
# clean data
clean_df = df.dropna(axis= 'rows')
clean_df = clean_df.loc[clean_df['sex'] != 'unknown']
clean_df.count()
# Out:
# lesion_id       9948
# image_id        9948
# dx              9948
# dx_type         9948
# age             9948
# sex             9948
# localization    9948
# dtype: int64

# %%
#add 'Age Groups' column
bins = [0, 39.9 ,49.9, 59.9, 69.9, 79.9, 100]
group_names = ['Under Forty', 'Forties', 'Fifties', 'Sixties', 'Seventies', 'Over Eighty']

clean_df2 = clean_df
clean_df2['Age Groups'] = pd.cut(clean_df2['age'], bins, labels=group_names, include_lowest=True)

# %%
clean_df2.groupby('sex')['dx'].value_counts().unstack(0).plot.bar(figsize=(20,12))
plt.title('dx vs. Sex')
plt.xlabel('dx')
plt.ylabel('Sex')
plt.rcParams.update({'font.size': 20})

plt.show()
